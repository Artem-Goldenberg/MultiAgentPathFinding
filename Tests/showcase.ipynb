# %%
import matplotlib.pyplot as plt
# %config InlineBackend.figure_formats = ['svg']
# %matplotlib inline

# %%
import test
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# ~ 2 min
test.test_correctness()
# Out:
# 49it [01:52,  2.30s/it]
# ️✅✅️✅ Congratulations! 🤩 Your algorithm hse passed all tests! 😎😎😎

# %%
baggy = "instances/exp0.txt"
regular = "instances/test_34.txt"
massive = "instances/test_54.txt"
strange = "instances/exp2_2.txt"
time_consumer_indeed = "instances/taylor1.txt" # very good for cbs pc

interesting = [
    baggy,
    strange,
    regular,
    massive,
    # time_consumer_indeed
]

# %%
for file in interesting:
    test.simple_test(file)
# Out:
# Testing 'find_agents_paths' algorithm on the map 'instances/exp0.txt':
# Found solution with cost = 8
# CPU time = 0.020443999999770313 seconds, Wall time = 0.020342111587524414 seconds
# --------------------------------------------------------------------------
#
# Testing 'find_agents_paths' algorithm on the map 'instances/exp2_2.txt':
# Found solution with cost = 8
# CPU time = 0.005403999999998632 seconds, Wall time = 0.00547480583190918 seconds
# --------------------------------------------------------------------------
#
# Testing 'find_agents_paths' algorithm on the map 'instances/test_34.txt':
# Found solution with cost = 33
# CPU time = 0.003062999999656313 seconds, Wall time = 0.0030548572540283203 seconds
# --------------------------------------------------------------------------
#
# Testing 'find_agents_paths' algorithm on the map 'instances/test_54.txt':
# Found solution with cost = 183
# CPU time = 3.2956529999996746 seconds, Wall time = 3.507878303527832 seconds
# ...

# %%
import Algorithms.cbs_pc as cbs_pc

# %%
test.test_correctness(cbs_pc.find_agents_paths)
# Out:
# 49it [03:25,  4.19s/it]
# ️✅✅️✅ Congratulations! 🤩 Your algorithm hse passed all tests! 😎😎😎

# %%
test.simple_test(time_consumer_indeed)
# Out:
# Testing 'find_agents_paths' algorithm on the map 'instances/taylor1.txt':
# Found solution with cost = 20
# CPU time = 221.38623099999995 seconds, Wall time = 221.70869898796082 seconds
# --------------------------------------------------------------------------

# %%
test.test_correctness(cbs.find_agents_paths)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 test.test_correctness(cbs.find_agents_paths)
#
# NameError: name 'cbs' is not defined

# %%
test.test_correctness(cbs_pc.find_agents_path2)
# Out:
# 40it [00:05,  6.94it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 test.test_correctness(cbs_pc.find_agents_path2)
#
# File ~/Developer/MultiAgentPathFinding/Tests/test.py:81, in test_correctness(algorithm, can_fail_before_quit)
#      79 task = MAPF()
#      80 task.read_txt(current_dir + '/' + name)
# ---> 81 result, _, _ = base_test(task, algorithm)
#      82 if result is None or result.cost != cost:
#      83     found_cost = result.cost if result is not None else '∞'
#
# File ~/Developer/MultiAgentPathFinding/Tests/test.py:50, in base_test(task, algorithm, show, save)
#      48 start_cpu_time = time.process_time()
#      49 start_wall_time = time.time()
# ---> 50 result = algorithm(task)
#      51 wall_time = time.time() - start_wall_time
#      52 cpu_time = time.process_time() - start_cpu_time
#
# ...

# %%
test.test_correctness(cbs_pc.find_agents_paths)
# Out:
# 49it [01:59,  2.43s/it]
# ️✅✅️✅ Congratulations! 🤩 Your algorithm hse passed all tests! 😎😎😎

# %%
test.simple_test(time_consumer_indeed, algorithms=[cbs_pc.find_agents_path2])
# Out:
# Testing 'find_agents_path2' algorithm on the map 'instances/taylor1.txt':
# Found solution with cost = 20
# CPU time = 210.106002 seconds, Wall time = 214.5247609615326 seconds
# Agent paths:
# [0] = (1, 5) -> (1, 4) -> (1, 3) -> cost = 2
# [1] = (1, 3) -> (1, 2) -> (1, 1) -> (2, 1) -> (3, 1) -> (3, 2) -> (3, 3) -> (3, 4) -> (3, 5) -> (3, 6) -> (3, 7) -> (3, 8) -> (3, 9) -> (2, 9) -> (1, 9) -> (1, 8) -> (1, 7) -> (1, 6) -> (1, 5) -> cost = 18
# --------------------------------------------------------------------------
